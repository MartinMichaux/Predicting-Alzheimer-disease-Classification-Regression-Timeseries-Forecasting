# %% [markdown]
# # Model Building
#
# better to plot with scatter plot, but many features so plot several scatter of one variable feature with all others kept constant

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import poisson
from sklearn.svm import SVC 
from sklearn.metrics import accuracy_score, classification_report
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
xgb.set_config(verbosity=0)
from sklearn.feature_selection import RFECV
import random
from sklearn.metrics import mean_squared_error
import sklearn.metrics as sm
from sklearn.cross_decomposition import PLSRegression

# %%
# Drop first column of dataframe
def drop_first_col(df):
    return df.iloc[: , 1:]

train = pd.read_csv("dataset\\train.csv")
test = pd.read_csv("dataset\\test.csv")

train = drop_first_col(train)
test = drop_first_col(test)

# %% [markdown]
# ## Test on VAR (Multi Variate Time Series)

# %%
#fit the model
from statsmodels.tsa.vector_ar.var_model import VAR

avg_rmse = []

for rid in train['RID'].unique():
    print('FOR RECORD',rid)
    
    VAR_train = (train.loc[train['RID']==rid]).drop(['RID','VISCODE'],axis=1)
    VAR_test = (test.loc[test['RID']==rid]).drop(['RID','VISCODE'],axis=1)

    model = VAR(endog=VAR_train)
    model_fit = model.fit(trend="nc")

    # make prediction on test set
    prediction = model_fit.forecast(model_fit.y, steps=len(VAR_test))

    #converting predictions to dataframe
    pred = pd.DataFrame(index=range(0,len(prediction)),columns=[VAR_train.columns])
    for j in range(0,13):
        for i in range(0, len(prediction)):
            pred.iloc[i][j] = prediction[i][j]

    print("prediction :",'\n',pred['MMSE'],'\n')
    print("true value :",'\n',VAR_test['MMSE'],'\n')
    #check rmse
    rmse = np.sqrt(mean_squared_error(pred['MMSE'], VAR_test['MMSE']))
    print('rmse value for MMSE is : ', rmse)
    avg_rmse.append(rmse)
# Out:
# FOR RECORD 4.0
# prediction :
#          MMSE
# 0  23.448252
# 1    20.8502
#
# true value :
#  0    27.0
# 1    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.862366972584036
# FOR RECORD 33.0
# prediction :
#     MMSE
# 0  30.0
# 1  13.0
#
# true value :
#  2    25.0
# 3    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  9.192388155425109
# FOR RECORD 41.0
# prediction :
#     MMSE
# 0  23.0
# 1  23.0
#
# true value :
#  4    24.0
# 5    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.7071067811865727
# FOR RECORD 42.0
# prediction :
#      MMSE
# 0   17.5
# 1  14.25
#
# true value :
#  6    22.0
# 7    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  6.957460025037833
# FOR RECORD 45.0
# prediction :
#          MMSE
# 0  25.287414
#
# true value :
#  8    22.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.287413525468235
# FOR RECORD 51.0
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# prediction :
#     MMSE
# 0  29.0
# 1  30.0
#
# true value :
#  9     28.0
# 10    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.9154759474226455
# FOR RECORD 57.0
# prediction :
#     MMSE
# 0   8.0
# 1  57.0
#
# true value :
#  11    20.0
# 12    14.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  31.56738823532876
# FOR RECORD 77.0
# prediction :
#     MMSE
# 0  26.0
# 1   4.0
#
# true value :
#  13    19.0
# 14    21.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  12.999999999999982
# FOR RECORD 101.0
# prediction :
#        MMSE
# 0    26.75
# 1  27.1875
#
# true value :
#  15    28.0
# 16    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.7815241017174128
# FOR RECORD 102.0
# prediction :
#    MMSE
# 0 -1.0
# 1  4.0
#
# true value :
#  17    8.0
# 18    5.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  6.403124237432687
# FOR RECORD 111.0
# prediction :
#          MMSE
# 0  11.118801
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# true value :
#  19    18.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  6.881199323280406
# FOR RECORD 112.0
# prediction :
#          MMSE
# 0  28.220189
# 1  28.882462
#
# true value :
#  20    29.0
# 21    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.5576379407886128
# FOR RECORD 126.0
# prediction :
#          MMSE
# 0  32.333333
# 1  35.777778
#
# true value :
#  22    26.0
# 23    22.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  10.722366147565944
# FOR RECORD 150.0
# prediction :
#      MMSE
# 0   26.5
# 1  24.75
#
# true value :
#  24    28.0
# 25    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.9121323175973062
# FOR RECORD 176.0
# prediction :
#          MMSE
# 0  27.737083
# 1  29.149385
#
# true value :
#  26    25.0
# 27    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.4608413408108674
# FOR RECORD 188.0
# prediction :
#     MMSE
# 0  29.0
# 1  27.0
#
# true value :
#  28    28.0
# 29    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.581138830084147
# FOR RECORD 190.0
# prediction :
#          MMSE
# 0  26.625915
# 1   29.77154
#
# true value :
#  30    26.0
# 31    24.0
# Name: MMSE, dtype: float64
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#
#
# rmse value for MMSE is :  4.105024187697769
# FOR RECORD 204.0
# prediction :
#     MMSE
# 0  24.0
# 1  24.0
#
# true value :
#  32    27.0
# 33    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.2360679774998244
# FOR RECORD 214.0
# prediction :
#     MMSE
# 0  21.0
# 1  19.0
#
# true value :
#  34    20.0
# 35    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.9154759474226326
# FOR RECORD 222.0
# prediction :
#          MMSE
# 0  19.697569
# 1  15.432856
#
# true value :
#  36    24.0
# 37    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  8.067696090372719
# FOR RECORD 231.0
# prediction :
#     MMSE
# 0  29.0
# 1  28.0
#
# true value :
#  38    25.0
# 39    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.915475947422628
# FOR RECORD 240.0
# prediction :
#          MMSE
# 0  31.580258
# 1  36.194748
#
# true value :
#  40    24.0
# 41    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  8.426259443171679
# FOR RECORD 243.0
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# prediction :
#         MMSE
# 0  17.82028
#
# true value :
#  42    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  8.17972046949248
# FOR RECORD 256.0
# prediction :
#     MMSE
# 0  19.0
# 1  18.0
#
# true value :
#  43    21.0
# 44    16.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.000000000000007
# FOR RECORD 269.0
# prediction :
#          MMSE
# 0  39.333333
# 1  65.555556
#
# true value :
#  45    22.0
# 46    21.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  33.805635442250164
# FOR RECORD 273.0
# prediction :
#     MMSE
# 0  29.0
# 1  29.0
#
# true value :
#  47    28.0
# 48    30.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.9999999999999964
# FOR RECORD 285.0
# prediction :
#          MMSE
# 0  29.777807
# 1  29.137727
#
# true value :
#  49    29.0
# 50    28.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.974527263227458
# FOR RECORD 291.0
# prediction :
#     MMSE
# 0  24.0
# 1  34.0
#
# true value :
#  51    30.0
# 52    28.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  6.000000000000043
# FOR RECORD 292.0
# prediction :
#     MMSE
# 0  18.0
# 1  38.0
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# true value :
#  53    22.0
# 54    22.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  11.661903789690426
# FOR RECORD 293.0
# prediction :
#          MMSE
# 0     26.125
# 1  26.296875
#
# true value :
#  55    24.0
# 56    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.5171947412288636
# FOR RECORD 294.0
# prediction :
#      MMSE
# 0   16.8
# 1  34.76
#
# true value :
#  57    26.0
# 58    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  10.55787857478959
# FOR RECORD 307.0
# prediction :
#     MMSE
# 0  32.0
# 1  31.0
#
# true value :
#  59    29.0
# 60    30.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.236067977499768
# FOR RECORD 314.0
# prediction :
#          MMSE
# 0  33.571429
# 1  38.306122
#
# true value :
#  61    26.0
# 62    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  10.216828772704487
# FOR RECORD 326.0
# prediction :
#      MMSE
# 0   27.5
# 1  23.25
#
# true value :
#  63    25.0
# 64    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.157834562704013
# FOR RECORD 331.0
# prediction :
#          MMSE
# 0  26.333333
# 1  27.777778
#
# true value :
#  65    26.0
# 66    23.0
# Name: MMSE, dtype: float64
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#
#
# rmse value for MMSE is :  3.386611256472966
# FOR RECORD 336.0
# prediction :
#          MMSE
# 0  22.511431
# 1  24.984235
#
# true value :
#  67    26.0
# 68    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.837895682778737
# FOR RECORD 344.0
# prediction :
#          MMSE
# 0  25.866377
# 1  28.669674
#
# true value :
#  69    23.0
# 70    20.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  6.45675475145395
# FOR RECORD 362.0
# prediction :
#     MMSE
# 0  22.0
# 1  21.0
#
# true value :
#  71    24.0
# 72    20.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.5811388300841873
# FOR RECORD 376.0
# prediction :
#     MMSE
# 0  30.0
# 1  33.0
#
# true value :
#  73    29.0
# 74    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.915475947423409
# FOR RECORD 378.0
# prediction :
#     MMSE
# 0  26.0
# 1  25.0
#
# true value :
#  75    26.0
# 76    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.4142135623730925
# FOR RECORD 388.0
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# prediction :
#     MMSE
# 0  29.0
# 1  27.0
#
# true value :
#  77    26.0
# 78    20.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  5.3851648071345
# FOR RECORD 394.0
# prediction :
#      MMSE
# 0   21.4
# 1  21.72
#
# true value :
#  79    20.0
# 80    18.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.8105515472945704
# FOR RECORD 410.0
# prediction :
#          MMSE
# 0  29.158674
#
# true value :
#  81    30.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.8413259789693406
# FOR RECORD 422.0
# prediction :
#     MMSE
# 0  31.0
# 1  31.0
#
# true value :
#  82    29.0
# 83    28.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.5495097567963625
# FOR RECORD 423.0
# prediction :
#          MMSE
# 0  27.643332
#
# true value :
#  84    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.643332125883973
# FOR RECORD 429.0
# prediction :
#          MMSE
# 0  24.333333
# 1  24.444444
#
# true value :
#  85    25.0
# 86    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.1967032904743524
# FOR RECORD 443.0
# prediction :
#          MMSE
# 0  31.333333
# 1  32.555556
#
# true value :
#  87    30.0
# 88    30.0
# Name: MMSE, dtype: float64
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#
#
# rmse value for MMSE is :  2.0382151475382417
# FOR RECORD 448.0
# prediction :
#     MMSE
# 0  32.0
# 1  22.0
#
# true value :
#  89    30.0
# 90    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.549509756796375
# FOR RECORD 476.0
# prediction :
#          MMSE
# 0  17.387443
# 1  11.846922
#
# true value :
#  91    20.0
# 92    24.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  8.789845397006767
# FOR RECORD 481.0
# prediction :
#     MMSE
# 0  32.0
# 1  30.0
#
# true value :
#  93    28.0
# 94    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.535533905932711
# FOR RECORD 501.0
# prediction :
#     MMSE
# 0  30.0
# 1  29.0
#
# true value :
#  95    29.0
# 96    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.5811388300841627
# FOR RECORD 511.0
# prediction :
#     MMSE
# 0  25.0
# 1  25.0
#
# true value :
#  97    25.0
# 98    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.4142135623730951
# FOR RECORD 514.0
# prediction :
#     MMSE
# 0  30.0
# 1  32.0
#
# true value :
#  99     28.0
# 100    28.0
# Name: MMSE, dtype: float64
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#
#
# rmse value for MMSE is :  3.1622776601683524
# FOR RECORD 531.0
# prediction :
#          MMSE
# 0  24.586742
#
# true value :
#  101    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.4132581543662823
# FOR RECORD 544.0
# prediction :
#          MMSE
# 0  30.875591
# 1  33.065386
#
# true value :
#  102    26.0
# 103    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  7.908330291330598
# FOR RECORD 552.0
# prediction :
#          MMSE
# 0   29.85195
# 1  34.684929
#
# true value :
#  104    24.0
# 105    24.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  8.614320447908023
# FOR RECORD 566.0
# prediction :
#      MMSE
# 0    7.0
# 1  110.0
#
# true value :
#  106    27.0
# 107    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  61.745445176137736
# FOR RECORD 567.0
# prediction :
#          MMSE
# 0  23.333333
# 1  22.555556
#
# true value :
#  108    23.0
# 109    20.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#  1.8223577185395787
# FOR RECORD 588.0
# prediction :
#     MMSE
# 0  24.0
# 1  18.0
#
# true value :
#  110    19.0
# 111    18.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.5355339059327475
# FOR RECORD 598.0
# prediction :
#          MMSE
# 0    27.2656
# 1  25.927863
#
# true value :
#  112    30.0
# 113    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.0417976342235025
# FOR RECORD 604.0
# prediction :
#      MMSE
# 0   27.2
# 1  26.84
#
# true value :
#  114    20.0
# 115    24.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  5.472915128156144
# FOR RECORD 607.0
# prediction :
#          MMSE
# 0  25.620317
# 1  22.510996
#
# true value :
#  116    30.0
# 117    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.959467835809556
# FOR RECORD 621.0
# prediction :
#          MMSE
# 0  23.740103
# 1  20.782918
#
# true value :
#  118    27.0
# 119    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.349992667584969
# FOR RECORD 625.0
# prediction :
#          MMSE
# 0   8.666667
# 1  14.222222
#
# true value :
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#  120    22.0
# 121    15.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  9.444117641404695
# FOR RECORD 626.0
# prediction :
#     MMSE
# 0  26.0
# 1  26.5
#
# true value :
#  122    23.0
# 123    24.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.761340254296779
# FOR RECORD 634.0
# prediction :
#          MMSE
# 0  32.333333
# 1  29.555556
#
# true value :
#  124    26.0
# 125    30.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.489356411297063
# FOR RECORD 638.0
# prediction :
#        MMSE
# 0    14.75
# 1  13.1875
#
# true value :
#  126    21.0
# 127    15.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.601502811582331
# FOR RECORD 649.0
# prediction :
#          MMSE
# 0   29.22156
# 1  32.275292
#
# true value :
#  128    26.0
# 129    19.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  9.659498480042009
# FOR RECORD 671.0
# prediction :
#     MMSE
# 0  22.0
# 1  29.5
#
# true value :
#  130    24.0
# 131    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.8504385627478426
# FOR RECORD 673.0
# prediction :
#          MMSE
# 0  24.666667
# 1  23.444444
#
# true value :
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# 132    28.0
# 133    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.9700147565829456
# FOR RECORD 697.0
# prediction :
#          MMSE
# 0  18.475844
# 1  14.937357
#
# true value :
#  134    26.0
# 135    24.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  8.328998526274754
# FOR RECORD 718.0
# prediction :
#     MMSE
# 0  49.0
# 1 -54.0
#
# true value :
#  136    28.0
# 137    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  57.801384066475464
# FOR RECORD 722.0
# prediction :
#      MMSE
# 0   28.5
# 1  28.75
#
# true value :
#  138    29.0
# 139    28.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.6373774391991002
# FOR RECORD 723.0
# prediction :
#     MMSE
# 0  27.0
# 1  27.0
#
# true value :
#  140    22.0
# 141    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.527692569068713
# FOR RECORD 725.0
# prediction :
#          MMSE
# 0  22.796899
# 1  19.992951
#
# true value :
#  142    26.0
# 143    24.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.6274166492836204
# FOR RECORD 729.0
# prediction :
#        MMSE
# 0    16.75
# 1  28.9375
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#
#
# true value :
#  144    23.0
# 145    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  6.095752875978491
# FOR RECORD 746.0
# prediction :
#     MMSE
# 0  30.0
# 1  29.0
#
# true value :
#  146    30.0
# 147    30.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.7071067811865023
# FOR RECORD 748.0
# prediction :
#          MMSE
# 0  16.672402
# 1   8.061018
#
# true value :
#  148    25.0
# 149    22.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  11.481378838345847
# FOR RECORD 769.0
# prediction :
#     MMSE
# 0  30.0
# 1  31.0
#
# true value :
#  150    28.0
# 151    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  5.830951894845316
# FOR RECORD 783.0
# prediction :
#     MMSE
# 0  29.0
# 1  29.0
#
# true value :
#  152    29.0
# 153    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.1213203435596024
# FOR RECORD 800.0
# prediction :
#     MMSE
# 0  31.0
# 1  34.0
#
# true value :
#  154    30.0
# 155    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.6055512754639167
# FOR RECORD 821.0
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# ...
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#
#
# true value :
#  207    25.0
# 208    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.6298006013006223
# FOR RECORD 1140.0
# prediction :
#     MMSE
# 0  22.0
# 1   9.0
#
# true value :
#  209    27.0
# 210    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  13.209844813622952
# FOR RECORD 1148.0
# prediction :
#          MMSE
# 0  24.837833
#
# true value :
#  211    20.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.837833175955925
# FOR RECORD 1168.0
# prediction :
#          MMSE
# 0  26.771524
# 1  23.755471
#
# true value :
#  212    28.0
# 213    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.808821182174991
# FOR RECORD 1187.0
# prediction :
#          MMSE
# 0  27.333333
# 1  27.555556
#
# true value :
#  214    29.0
# 215    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.5595187608465373
# FOR RECORD 1213.0
# prediction :
#          MMSE
# 0  23.747858
# 1  24.523495
#
# true value :
#  216    20.0
# 217    18.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  5.319888302144861
# FOR RECORD 1217.0
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# prediction :
#     MMSE
# 0  24.0
# 1  22.5
#
# true value :
#  218    27.0
# 219    30.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  5.711829829397902
# FOR RECORD 1224.0
# prediction :
#      MMSE
# 0   21.9
# 1  28.11
#
# true value :
#  220    28.0
# 221    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.564104512387933
# FOR RECORD 1246.0
# prediction :
#     MMSE
# 0  30.0
# 1  30.0
#
# true value :
#  222    30.0
# 223    28.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.4142135623731553
# FOR RECORD 1247.0
# prediction :
#          MMSE
# 0  19.442747
# 1  19.929058
#
# true value :
#  224    23.0
# 225    21.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.6268768132362617
# FOR RECORD 1260.0
# prediction :
#        MMSE
# 0    28.25
# 1  27.8125
#
# true value :
#  226    26.0
# 227    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.042994891085108
# FOR RECORD 1265.0
# prediction :
#          MMSE
# 0  26.666667
# 1  25.222222
#
# true value :
#  228    27.0
# 229    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#  1.2789849370245248
# FOR RECORD 1268.0
# prediction :
#     MMSE
# 0  29.0
# 1  29.0
#
# true value :
#  230    30.0
# 231    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.7071067811865425
# FOR RECORD 1269.0
# prediction :
#     MMSE
# 0  25.0
# 1  22.0
#
# true value :
#  232    29.0
# 233    28.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  5.099019513592816
# FOR RECORD 1292.0
# prediction :
#          MMSE
# 0  21.634233
#
# true value :
#  234    15.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  6.634232807080224
# FOR RECORD 1293.0
# prediction :
#          MMSE
# 0  25.243616
# 1  22.612222
#
# true value :
#  235    26.0
# 236    23.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.6010361142879013
# FOR RECORD 1295.0
# prediction :
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#         MMSE
# 0  24.282819
#
# true value :
#  237    25.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.7171807612225294
# FOR RECORD 1309.0
# prediction :
#     MMSE
# 0  30.0
# 1  31.0
#
# true value :
#  238    28.0
# 239    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.8078865529319605
# FOR RECORD 1321.0
# prediction :
#     MMSE
# 0  28.0
# 1  28.0
#
# true value :
#  240    29.0
# 241    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  0.9999999999999876
# FOR RECORD 1352.0
# prediction :
#     MMSE
# 0  31.0
# 1  32.0
#
# true value :
#  242    28.0
# 243    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  2.9999999999999947
# FOR RECORD 1380.0
# prediction :
#      MMSE
# 0   31.2
# 1  30.84
#
# true value :
#  244    29.0
# 245    27.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.129344979384655
# FOR RECORD 1393.0
# prediction :
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
#          MMSE
# 0  24.666667
# 1  24.222222
#
# true value :
#  246    20.0
# 247    19.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  4.952241044014773
# FOR RECORD 1394.0
# prediction :
#          MMSE
# 0  12.857143
# 1  11.122449
#
# true value :
#  248    24.0
# 249    11.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  7.879665572177711
# FOR RECORD 1398.0
# prediction :
#          MMSE
# 0  20.246012
#
# true value :
#  250    15.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  5.246011532220919
# FOR RECORD 1419.0
# prediction :
#     MMSE
# 0  39.0
# 1 -12.0
#
# true value :
#  251    29.0
# 252    29.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  29.841246622752468
# FOR RECORD 1421.0
# prediction :
#          MMSE
# 0  28.864668
# 1  30.581985
#
# true value :
#  253    27.0
# 254    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  3.4979691396669397
# FOR RECORD 1423.0
# prediction :
#          MMSE
# 0  27.008371
#
# true value :
#  255    26.0
# Name: MMSE, dtype: float64
#
# rmse value for MMSE is :  1.0083711222063236
# AVG RMSE: 5.623294137993409
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\marti\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
print('AVG RMSE:',sum(avg_rmse) / len(avg_rmse))
